# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/substrate')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/substrate

# %%
# !pip install -q timm wandb pytorch_lightning torchmetrics tqdm
# !pip install -q hydra-core --upgrade

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python inference.py --timm_name convnext_base \
                     --model_name sleek-shape-45-4 \
                     --wandb_run_path insilicomab/substrate/366jyvg6 \
                     --data_ver v4 \
                     --image_size 224
# Out:
# device: cpu
# 100 predictions done!
# 200 predictions done!
