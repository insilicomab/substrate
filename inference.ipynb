# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/substrate')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/substrate

# %%
# !pip install -q timm wandb pytorch_lightning torchmetrics tensorboard
# !pip install -q hydra-core --upgrade

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: insilicomab. Use `wandb login --relogin` to force relogin

# %%
# !python inference.py --timm_name convnext_base \
                     --model_name generous-night-1 \
                     --wandb_run_path insilicomab/substrate/zalxevzv \
                     --data_ver v1 \
                     --image_size 224
# Out:
# device: cpu
# 100 predictions done!
# 200 predictions done!
